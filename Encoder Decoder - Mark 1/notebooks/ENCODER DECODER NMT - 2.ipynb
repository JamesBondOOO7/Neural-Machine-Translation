# %%
# !pip install torchtext==0.6.0 --quiet
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext.datasets import Multi30k
from torchtext.data import Field, BucketIterator
import numpy as np
import spacy
import random
from torch.utils.tensorboard import SummaryWriter  # to print to tensorboard

# %%
# !python -m spacy download de --quiet
# !python -m spacy download en --quiet
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('de_core_news_sm')
# ✔ Linking successful
# /opt/conda/lib/python3.7/site-packages/de_core_news_sm -->
# /opt/conda/lib/python3.7/site-packages/spacy/data/de
# You can now load the model via spacy.load('de')
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /opt/conda/lib/python3.7/site-packages/en_core_web_sm -->
# /opt/conda/lib/python3.7/site-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
spacy_ger = spacy.load('de')
spacy_eng = spacy.load('en')

def tokenizer_ger(text):
    return [tok.text for tok in spacy_ger.tokenizer(text)]

def tokenizer_eng(text):
    return [tok.text for tok in spacy_eng.tokenizer(text)]

german = Field(tokenize=tokenizer_ger,
               lower=True,
               init_token = '<sos>',
               eos_token = '<eos>'
        )

english = Field(tokenize=tokenizer_eng,
                lower=True,
                init_token = '<sos>',
                eos_token = '<eos>'
        )

# train_data, validation_data, test_data = Multi30k.splits(exts=('.de', '.en'),fields=(german, english))
train_data, valid_data, test_data = Multi30k.splits(
    exts=(".de", ".en"), fields=(german, english)
)


german.build_vocab(train_data, max_size=10000, min_freq=2)
english.build_vocab(train_data, max_size=10000, min_freq=2)
# Out:
# downloading training.tar.gz
# training.tar.gz: 100%|██████████| 1.21M/1.21M [00:00<00:00, 1.32MB/s]
# downloading validation.tar.gz
# validation.tar.gz: 100%|██████████| 46.3k/46.3k [00:00<00:00, 231kB/s]
# downloading mmt_task1_test2016.tar.gz
# mmt_task1_test2016.tar.gz: 100%|██████████| 66.2k/66.2k [00:00<00:00, 222kB/s]

# %%
class Encoder(nn.Module):

    def __init__(self, input_size, embedding_size, hidden_size, num_layers, p):
        
        super(Encoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.dropout = nn.Dropout(p)
        self.embedding = nn.Embedding(input_size, embedding_size)
        self.rnn = nn.LSTM(embedding_size, hidden_size, num_layers, dropout=p)

    def forward(self, x):

        # x shape : (seq_length, N)

        embedding = self.dropout(self.embedding(x))
        # embedding shape : (seq_length, N, embedding_size)

        outputs, (hidden, cell) = self.rnn(embedding)

        return hidden, cell

# %%
class Decoder(nn.Module):

    def __init__(self, input_size, embedding_size, hidden_size, output_size, num_layers, p):
        # Note : input_size = output_size !!

        super(Decoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.dropout = nn.Dropout(p)
        self.embedding = nn.Embedding(input_size, embedding_size)
        self.rnn = nn.LSTM(embedding_size, hidden_size, num_layers, dropout=p)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden, cell):
        # shape of x : (N,), but we want (1, N)
        x = x.unsqueeze(0)

        embedding = self.dropout(self.embedding(x))
        # embedding shape : (1, N, embedding_size)

        outputs, (hidden, cell) = self.rnn(embedding, (hidden, cell))
        # outputs shape : (1, N, hidden_size)

        predictions = self.fc(outputs)
        # predictions shape : (1, N, length_of_vocab)

        predictions = predictions.squeeze(0)

        return predictions, hidden, cell

# %%
class Seq2Seq(nn.Module):

    def __init__(self, encoder, decoder):
        super(Seq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        
    def forward(self, source, target, teacher_force_ratio=0.5):

        batch_size = source.shape[1]
        target_len = target.shape[0]
        target_vocab_size = len(english.vocab)

        hidden, cell = self.encoder(source)

        outputs = torch.zeros(target_len, batch_size, target_vocab_size).to(device)
        # <sos> token
        x = target[0]
        for t in range(1, target_len):

            output, hidden, cell = self.decoder(x, hidden, cell)
            
            outputs[t] = output

            # (N, english_vocab) , selcting best index for each sentence N
            best_guess = output.argmax(1)

            x = target[t] if random.random() < teacher_force_ratio else best_guess

        return outputs

# %%
# Training

# training hyperparameters
num_epochs = 100
learning_rate = 0.001
batch_size = 64

# model parameters
load_model = False
device = torch.device('cuda' if torch.cuda.is_available() else "cpu")
input_size_encoder = len(german.vocab)
input_size_decoder = len(english.vocab)
output_size = len(english.vocab)
encoder_embedding_size = 300
decoder_embedding_size = 300
hidden_size = 1024
num_layers = 2
enc_dropout = 0.5
dec_dropout = 0.5

# tensorboard
writer = SummaryWriter(f'runs/loss_plot')
step = 0

# %%
train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data),
    batch_size=batch_size,
    sort_within_batch = True,
    sort_key = lambda x : len(x.src),
    device = device
)

encoder_net = Encoder(input_size_encoder, encoder_embedding_size,
                      hidden_size, num_layers, enc_dropout).to(device)

decoder_net = Decoder(input_size_decoder, decoder_embedding_size,
                      hidden_size, output_size, num_layers, dec_dropout).to(device)

model = Seq2Seq(encoder_net, decoder_net)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# ignore the pad idx while training
pad_idx = english.vocab.stoi['<pad>']
criterion = nn.CrossEntropyLoss(ignore_index=pad_idx)

# %%
# utils
import torch
import spacy
from torchtext.data.metrics import bleu_score
import sys


def translate_sentence(model, sentence, german, english, device, max_length=50):
    # print(sentence)

    # sys.exit()

    # Load german tokenizer
    spacy_ger = spacy.load("de")

    # Create tokens using spacy and everything in lower case (which is what our vocab is)
    if type(sentence) == str:
        tokens = [token.text.lower() for token in spacy_ger(sentence)]
    else:
        tokens = [token.lower() for token in sentence]

    # print(tokens)

    # sys.exit()
    # Add <SOS> and <EOS> in beginning and end respectively
    tokens.insert(0, german.init_token)
    tokens.append(german.eos_token)

    # Go through each german token and convert to an index
    text_to_indices = [german.vocab.stoi[token] for token in tokens]

    # Convert to Tensor
    sentence_tensor = torch.LongTensor(text_to_indices).unsqueeze(1).to(device)

    # Build encoder hidden, cell state
    with torch.no_grad():
        hidden, cell = model.encoder(sentence_tensor)

    outputs = [english.vocab.stoi["<sos>"]]

    for _ in range(max_length):
        previous_word = torch.LongTensor([outputs[-1]]).to(device)

        with torch.no_grad():
            output, hidden, cell = model.decoder(previous_word, hidden, cell)
            output = output.reshape(1,-1)
            # print(output.shape)
            # print(output.argmax(1).squeeze(0))
            # print(output.argmax(1).item())
            best_guess = output.argmax(1).item()

        outputs.append(best_guess)

        # Model predicts it's the end of the sentence
        if output.argmax(1).item() == english.vocab.stoi["<eos>"]:
            break

    translated_sentence = [english.vocab.itos[idx] for idx in outputs]

    # remove start token
    return translated_sentence[1:]


def bleu(data, model, german, english, device):
    targets = []
    outputs = []

    for example in data:
        src = vars(example)["src"]
        trg = vars(example)["trg"]

        prediction = translate_sentence(model, src, german, english, device)
        prediction = prediction[:-1]  # remove <eos> token

        targets.append([trg])
        outputs.append(prediction)

    return bleu_score(outputs, targets)


def save_checkpoint(state, filename="my_checkpoint.pth.tar"):
    print("=> Saving checkpoint")
    torch.save(state, filename)


def load_checkpoint(checkpoint, model, optimizer):
    print("=> Loading checkpoint")
    model.load_state_dict(checkpoint["state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer"])

# %%
if load_model:
    load_checkpoint(torch.load('my_checkpoint.pth.ptar'), model, optimizer)

sentence = "ein boot mit mehreren männern darauf wird von einem großen pferdegespann ans ufer gezogen."

for epoch in range(num_epochs):
    print(f"Epoch : [{epoch + 1} / {num_epochs}]")

    checkpoint = {
                'state_dict': model.state_dict(),
                'optimizer': optimizer.state_dict()
                }

    save_checkpoint(checkpoint)

    model.eval()

    translated_sentence = translate_sentence(model, sentence, german, 
                                             english, device, max_length=50)
    
    print(f"Translated Sentence {epoch + 1}/{num_epochs} : {translated_sentence}")

    model.train()
    
    for batch_idx, batch in enumerate(train_iterator):

        inp_data = batch.src.to(device)
        target = batch.trg.to(device)

        output = model.forward(source=inp_data, target=target)
        # output shape : (trg_len, batch_size, output_dim)

        # (N, 10) and targets would be (N,)
        output = output[1:].reshape(-1, output.shape[2])
        target = target[1:].reshape(-1)

        optimizer.zero_grad()
        loss = criterion(output, target)

        loss.backward()

        # to avoid exploding gradient problem
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)
        optimizer.step()

        writer.add_scalar('Training Loss', loss, global_step = step)
        step +=  1
# Out:
# Epoch : [1 / 100]
# => Saving checkpoint
# Translated Sentence 1/100 : ['ad', 'walmart', 'road', 'balanced', 'balanced', 'litter', 'clock', 'litter', 'tea', 'tea', 'tea', 'cheering', 'diners', 'steals', 'stockings', 'sushi', 'sushi', 'headphones', 'headphones', 'natural', 'tan', 'headphones', 'tan', 'toy', 'headphones', 'clown', 'clown', 'acting', 'via', 'probably', 'probably', 'pineapples', 'pineapples', 'wrestlers', 'wrestlers', 'cameraman', 'slim', 'trap', 'cause', '11', 'tribe', 'cast', 'turbans', 'accompanied', 'accompanied', 'surfboard', 'temporary', 'dyed', 'acrobat', 'acrobat']
# Epoch : [2 / 100]
# => Saving checkpoint
# Translated Sentence 2/100 : ['a', 'young', 'girl', 'is', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', '.', '<eos>']
# Epoch : [3 / 100]
# => Saving checkpoint
# Translated Sentence 3/100 : ['a', '<unk>', 'player', 'in', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', '.', '.', '<eos>']
# Epoch : [4 / 100]
# => Saving checkpoint
# Translated Sentence 4/100 : ['a', 'street', 'with', 'a', '<unk>', 'in', 'a', 'of', 'a', 'a', 'a', 'a', '.', '<eos>']
# Epoch : [5 / 100]
# => Saving checkpoint
# Translated Sentence 5/100 : ['a', 'street', 'with', 'a', 'large', '<unk>', 'is', 'being', '<unk>', 'in', 'front', 'of', 'a', 'large', '.', '.', '<eos>']
# Epoch : [6 / 100]
# => Saving checkpoint
# Translated Sentence 6/100 : ['a', 'fisherman', 'with', 'with', 'a', 'large', 'number', 'is', 'being', 'pulled', 'by', 'a', 'large', '<unk>', '.', '<eos>']
# Epoch : [7 / 100]
# => Saving checkpoint
# Translated Sentence 7/100 : ['a', 'boat', 'with', 'a', 'large', 'number', 'is', 'being', 'pulled', 'by', 'a', 'large', 'large', '.', '.', '<eos>']
# Epoch : [8 / 100]
# => Saving checkpoint
# Translated Sentence 8/100 : ['a', 'boat', 'with', 'many', 'people', 'is', 'pulled', 'by', 'a', 'large', 'large', '<unk>', '.', '<eos>']
# Epoch : [9 / 100]
# => Saving checkpoint
# Translated Sentence 9/100 : ['a', 'boat', 'boat', 'with', 'many', 'large', 'people', 'is', 'pulled', 'by', 'a', 'large', 'large', '.', '.', '<eos>']
# Epoch : [10 / 100]
# => Saving checkpoint
# Translated Sentence 10/100 : ['a', 'boat', 'boat', 'with', 'many', 'people', 'from', 'a', 'large', 'large', 'large', 'large', '.', '.', '<eos>']
# Epoch : [11 / 100]
# => Saving checkpoint
# Translated Sentence 11/100 : ['a', 'boat', 'with', 'many', 'passengers', 'is', 'pulled', 'by', 'a', 'large', 'tree', 'by', 'a', 'large', 'building', '.', '<eos>']
# Epoch : [12 / 100]
# => Saving checkpoint
# Translated Sentence 12/100 : ['a', 'boat', 'boat', 'with', 'many', 'people', 'pulled', 'out', 'from', 'a', 'large', 'large', 'river', '.', '<eos>']
# Epoch : [13 / 100]
# => Saving checkpoint
# Translated Sentence 13/100 : ['a', 'boat', 'boat', 'with', 'many', 'people', 'has', 'pulled', 'by', 'a', 'large', 'cable', '.', '<eos>']
# Epoch : [14 / 100]
# => Saving checkpoint
# Translated Sentence 14/100 : ['a', 'boat', 'boat', 'with', 'a', 'large', 'full', 'of', 'people', 'is', 'pulled', 'by', 'a', 'large', 'cable', '.', '<eos>']
# Epoch : [15 / 100]
# => Saving checkpoint
# Translated Sentence 15/100 : ['a', 'boat', 'with', 'many', 'men', 'in', 'pulled', 'by', 'a', 'large', 'large', 'large', '.', '.', '<eos>']
# Epoch : [16 / 100]
# => Saving checkpoint
# Translated Sentence 16/100 : ['a', 'boat', 'boat', 'with', 'many', 'people', 'is', 'pulled', 'by', 'a', 'large', 'cable', 'of', 'a', '.', '<eos>']
# Epoch : [17 / 100]
# => Saving checkpoint
# Translated Sentence 17/100 : ['a', 'boat', 'boat', 'with', 'many', 'people', 'from', 'a', 'large', 'large', 'tree', '.', '<eos>']
# Epoch : [18 / 100]
# => Saving checkpoint
# Translated Sentence 18/100 : ['a', 'boat', 'boat', 'with', 'many', 'people', 'is', 'pulled', 'by', 'a', 'large', 'cable', 'of', 'large', 'fish', '.', '<eos>']
# Epoch : [19 / 100]
# => Saving checkpoint
# Translated Sentence 19/100 : ['a', 'boat', 'with', 'many', 'people', 'is', 'pulled', 'by', 'a', 'large', '<unk>', 'by', 'a', 'large', 'river', '.', '<eos>']
# Epoch : [20 / 100]
# => Saving checkpoint
# Translated Sentence 20/100 : ['a', 'boat', 'boat', 'with', 'many', 'people', 'is', 'pulled', 'by', 'a', 'large', 'cable', 'of', 'a', 'horses', '.', '<eos>']
# Epoch : [21 / 100]
# => Saving checkpoint
# Translated Sentence 21/100 : ['a', 'boat', 'boat', 'many', 'men', 'is', 'pulled', 'by', 'a', 'large', 'by', 'a', 'large', 'big', 'horses', '.', '<eos>']
# Epoch : [22 / 100]
# => Saving checkpoint
# Translated Sentence 22/100 : ['a', 'boat', 'carrying', 'many', 'men', 'is', 'pulled', 'pulled', 'by', 'a', 'large', 'river', 'of', 'a', 'horses', '.', '<eos>']
# Epoch : [23 / 100]
# => Saving checkpoint
# Translated Sentence 23/100 : ['a', 'boat', 'boat', 'many', 'men', 'is', 'pulled', 'in', 'a', 'large', 'river', 'of', 'horses', '.', 'horses', '.', '<eos>']
# Epoch : [24 / 100]
# => Saving checkpoint
# Translated Sentence 24/100 : ['a', 'boat', 'boat', 'with', 'many', 'men', 'is', 'out', 'of', 'a', 'large', ',', '<unk>', 'by', 'horses', '.', '<eos>']
# Epoch : [25 / 100]
# => Saving checkpoint
# Translated Sentence 25/100 : ['a', 'boat', 'boat', 'with', 'many', 'men', 'is', 'pulled', 'pulled', 'from', 'a', 'large', 'large', 'river', '.', '<eos>']
# Epoch : [26 / 100]
# => Saving checkpoint
# Translated Sentence 26/100 : ['a', 'boat', 'carrying', 'carrying', 'many', 'men', 'is', 'pulled', 'up', 'a', 'large', 'large', 'large', 'cable', 'of', 'horses', '.', '<eos>']
# Epoch : [27 / 100]
# => Saving checkpoint
# Translated Sentence 27/100 : ['a', 'boat', 'carrying', 'many', 'men', 'is', 'pulled', 'by', 'a', 'large', '<unk>', 'of', 'large', 'horses', '.', 'horses', '.', '<eos>']
# Epoch : [28 / 100]
# => Saving checkpoint
# Translated Sentence 28/100 : ['a', 'boat', 'boat', 'with', 'many', 'men', 'is', 'pulled', 'by', 'a', 'large', 'large', 'large', 'river', '.', '<eos>']
# Epoch : [29 / 100]
# => Saving checkpoint
# Translated Sentence 29/100 : ['a', 'boat', 'boat', 'with', 'many', 'men', 'is', 'pulled', 'out', 'of', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [30 / 100]
# => Saving checkpoint
# Translated Sentence 30/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'by', 'a', 'large', 'large', 'of', 'large', 'horses', '.', '<eos>']
# Epoch : [31 / 100]
# => Saving checkpoint
# Translated Sentence 31/100 : ['a', 'boat', 'carrying', 'several', 'men', 'pulled', 'by', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [32 / 100]
# => Saving checkpoint
# Translated Sentence 32/100 : ['a', 'boat', 'boat', 'with', 'many', 'different', 'dry', ',', 'are', 'being', 'pulled', 'by', 'a', 'large', 'cable', 'of', 'horses', '.', '<eos>']
# Epoch : [33 / 100]
# => Saving checkpoint
# Translated Sentence 33/100 : ['a', 'boat', 'boat', 'carrying', 'several', 'different', 'out', 'of', 'shore', 'across', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [34 / 100]
# => Saving checkpoint
# Translated Sentence 34/100 : ['a', 'boat', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'pulled', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [35 / 100]
# => Saving checkpoint
# Translated Sentence 35/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'pulled', 'by', 'a', 'large', 'group', 'of', 'horses', '.', '<eos>']
# Epoch : [36 / 100]
# => Saving checkpoint
# Translated Sentence 36/100 : ['a', 'boat', 'carrying', 'carrying', 'many', 'different', 'pulled', 'by', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [37 / 100]
# => Saving checkpoint
# Translated Sentence 37/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'by', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [38 / 100]
# => Saving checkpoint
# Translated Sentence 38/100 : ['a', 'boat', 'carrying', 'several', 'men', 'pulled', 'pulled', 'from', 'a', 'shore', 'of', 'a', 'large', ',', '.', '<eos>']
# Epoch : [39 / 100]
# => Saving checkpoint
# Translated Sentence 39/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'by', 'a', 'shore', 'of', 'a', 'large', 'horses', '.', '<eos>']
# Epoch : [40 / 100]
# => Saving checkpoint
# Translated Sentence 40/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'by', 'shore', 'of', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [41 / 100]
# => Saving checkpoint
# Translated Sentence 41/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'by', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [42 / 100]
# => Saving checkpoint
# Translated Sentence 42/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'by', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [43 / 100]
# => Saving checkpoint
# Translated Sentence 43/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'by', 'shore', 'from', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [44 / 100]
# => Saving checkpoint
# Translated Sentence 44/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', 'horses', '.', '<eos>']
# Epoch : [45 / 100]
# => Saving checkpoint
# Translated Sentence 45/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'pulled', 'by', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [46 / 100]
# => Saving checkpoint
# Translated Sentence 46/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'shore', 'by', 'shore', 'by', 'a', 'large', 'team', 'horses', '.', '<eos>']
# Epoch : [47 / 100]
# => Saving checkpoint
# Translated Sentence 47/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'shore', 'by', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [48 / 100]
# => Saving checkpoint
# Translated Sentence 48/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [49 / 100]
# => Saving checkpoint
# Translated Sentence 49/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'shore', 'shore', 'by', 'shore', 'of', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [50 / 100]
# => Saving checkpoint
# Translated Sentence 50/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'shore', 'by', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [51 / 100]
# => Saving checkpoint
# Translated Sentence 51/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [52 / 100]
# => Saving checkpoint
# Translated Sentence 52/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'shore', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [53 / 100]
# => Saving checkpoint
# Translated Sentence 53/100 : ['a', 'boat', 'carrying', 'several', 'men', 'pulled', 'by', 'shore', 'by', 'a', 'large', 'team', 'of', 'large', 'fish', '.', '<eos>']
# Epoch : [54 / 100]
# => Saving checkpoint
# Translated Sentence 54/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'by', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [55 / 100]
# => Saving checkpoint
# Translated Sentence 55/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [56 / 100]
# => Saving checkpoint
# Translated Sentence 56/100 : ['a', 'boat', 'carrying', 'several', 'men', 'pulled', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [57 / 100]
# => Saving checkpoint
# Translated Sentence 57/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [58 / 100]
# => Saving checkpoint
# Translated Sentence 58/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [59 / 100]
# => Saving checkpoint
# Translated Sentence 59/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [60 / 100]
# => Saving checkpoint
# Translated Sentence 60/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [61 / 100]
# => Saving checkpoint
# Translated Sentence 61/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [62 / 100]
# => Saving checkpoint
# Translated Sentence 62/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [63 / 100]
# => Saving checkpoint
# Translated Sentence 63/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [64 / 100]
# => Saving checkpoint
# Translated Sentence 64/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [65 / 100]
# => Saving checkpoint
# Translated Sentence 65/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [66 / 100]
# => Saving checkpoint
# Translated Sentence 66/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [67 / 100]
# => Saving checkpoint
# Translated Sentence 67/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [68 / 100]
# => Saving checkpoint
# Translated Sentence 68/100 : ['a', 'boat', 'with', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [69 / 100]
# => Saving checkpoint
# Translated Sentence 69/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'shore', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [70 / 100]
# => Saving checkpoint
# Translated Sentence 70/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'shore', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [71 / 100]
# => Saving checkpoint
# Translated Sentence 71/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'by', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [72 / 100]
# => Saving checkpoint
# Translated Sentence 72/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [73 / 100]
# => Saving checkpoint
# Translated Sentence 73/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'shore', 'by', 'a', 'large', 'team', 'of', 'caught', '.', '<eos>']
# Epoch : [74 / 100]
# => Saving checkpoint
# Translated Sentence 74/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [75 / 100]
# => Saving checkpoint
# Translated Sentence 75/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [76 / 100]
# => Saving checkpoint
# Translated Sentence 76/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [77 / 100]
# => Saving checkpoint
# Translated Sentence 77/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'by', 'shore', 'from', 'a', 'large', 'cable', 'of', 'horses', '.', '<eos>']
# Epoch : [78 / 100]
# => Saving checkpoint
# Translated Sentence 78/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [79 / 100]
# => Saving checkpoint
# Translated Sentence 79/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [80 / 100]
# => Saving checkpoint
# Translated Sentence 80/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [81 / 100]
# => Saving checkpoint
# Translated Sentence 81/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [82 / 100]
# => Saving checkpoint
# Translated Sentence 82/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [83 / 100]
# => Saving checkpoint
# Translated Sentence 83/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [84 / 100]
# => Saving checkpoint
# Translated Sentence 84/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [85 / 100]
# => Saving checkpoint
# Translated Sentence 85/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [86 / 100]
# => Saving checkpoint
# Translated Sentence 86/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [87 / 100]
# => Saving checkpoint
# Translated Sentence 87/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [88 / 100]
# => Saving checkpoint
# Translated Sentence 88/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [89 / 100]
# => Saving checkpoint
# Translated Sentence 89/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [90 / 100]
# => Saving checkpoint
# Translated Sentence 90/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [91 / 100]
# => Saving checkpoint
# Translated Sentence 91/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [92 / 100]
# => Saving checkpoint
# Translated Sentence 92/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'shore', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [93 / 100]
# => Saving checkpoint
# Translated Sentence 93/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [94 / 100]
# => Saving checkpoint
# Translated Sentence 94/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [95 / 100]
# => Saving checkpoint
# Translated Sentence 95/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [96 / 100]
# => Saving checkpoint
# Translated Sentence 96/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [97 / 100]
# => Saving checkpoint
# Translated Sentence 97/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [98 / 100]
# => Saving checkpoint
# Translated Sentence 98/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [99 / 100]
# => Saving checkpoint
# Translated Sentence 99/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']
# Epoch : [100 / 100]
# => Saving checkpoint
# Translated Sentence 100/100 : ['a', 'boat', 'carrying', 'several', 'men', 'is', 'pulled', 'to', 'shore', 'by', 'a', 'large', 'team', 'of', 'horses', '.', '<eos>']

# %%
score = bleu(test_data[1:100], model, german, english, device)
print(f"Bleu score {score*100:.2f}")
# Out:
# Bleu score 16.85
